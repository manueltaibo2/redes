# %%
#tarea 1.1
import requests

r = requests.get("https://httpbin.org/html")
print("Status:", r.status_code)
print("Headers:", r.headers)
print("Body:", r.text)
# Out:
# Status: 200
# Headers: {'Date': 'Wed, 25 Feb 2026 10:29:45 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '3741', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Body: <!DOCTYPE html>
# <html>
#   <head>
#   </head>
#   <body>
#       <h1>Herman Melville - Moby-Dick</h1>
#
#       <div>
#         <p>
# ...

# %%
#tarea 1.2
r = requests.get("https://httpbin.org/html2")
print("Status:", r.status_code)
print("Headers:", r.headers)
print("Body:", r.text)
# Out:
# Status: 404
# Headers: {'Date': 'Wed, 25 Feb 2026 10:29:53 GMT', 'Content-Type': 'text/html', 'Content-Length': '233', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Body: <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <title>404 Not Found</title>
# <h1>Not Found</h1>
# <p>The requested URL was not found on the server.  If you entered the URL manually please check your spelling and try again.</p>

# %%
#tarea 1.3
r = requests.get("https://httpbin.org/forms/post")
print("Status:", r.status_code)
print("Headers:", r.headers)
print("Body:", r.text)
# Out:
# Status: 200
# Headers: {'Date': 'Wed, 25 Feb 2026 10:29:59 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '1397', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Body: <!DOCTYPE html>
# <html>
#   <head>
#   </head>
#   <body>
#   <!-- Example form from HTML5 spec http://www.w3.org/TR/html5/forms.html#writing-a-form's-user-interface -->
#   <form method="post" action="/post">
#    <p><label>Customer name: <input name="custname"></label></p>
#    <p><label>Telephone: <input type=tel name="custtel"></label></p>
#    <p><label>E-mail address: <input type=email name="custemail"></label></p>
#    <fieldset>
#     <legend> Pizza Size </legend>
#     <p><label> <input type=radio name=size value="small"> Small </label></p>
#     <p><label> <input type=radio name=size value="medium"> Medium </label></p>
#     <p><label> <input type=radio name=size value="large"> Large </label></p>
# ...

# %%
#tarea 1.4
data = {
    "custname": "Juan García",
    "custtel": "612345678",
    "custemail": "juan@example.com",
    "size": "medium",
    "topping": ["cheese", "bacon"],
}

r = requests.post("https://httpbin.org/post", data=data)
print("Status:", r.status_code)
print("Headers:", r.headers)
print("Body:", r.text)
# Out:
# Status: 200
# Headers: {'Date': 'Wed, 25 Feb 2026 10:30:08 GMT', 'Content-Type': 'application/json', 'Content-Length': '644', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Body: {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "custemail": "juan@example.com",
#     "custname": "Juan Garc\u00eda",
#     "custtel": "612345678",
#     "size": "medium",
#     "topping": [
#       "cheese",
#       "bacon"
#     ]
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "113",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.5",
#     "X-Amzn-Trace-Id": "Root=1-699ecf30-42350781598a1ccc3c931684"
#   },
#   "json": null,
#   "origin": "193.144.61.240",
#   "url": "https://httpbin.org/post"
# }

# %%
#tarea 2
import socket

s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

s.connect(("httpbin.org", 80))

peticion = (
    "GET /html HTTP/1.1\r\n"
    "Host: httpbin.org\r\n"
    "\r\n"
)

s.send(peticion.encode())

respuesta = b""
while True:
    datos = s.recv(4096)
    if not datos:
        break
    respuesta += datos
    
s.close()

print(respuesta.decode())
# Out:
# HTTP/1.1 200 OK
# Date: Wed, 25 Feb 2026 10:30:35 GMT
# Content-Type: text/html; charset=utf-8
# Content-Length: 3741
# Connection: keep-alive
# Server: gunicorn/19.9.0
# Access-Control-Allow-Origin: *
# Access-Control-Allow-Credentials: true
#
# <!DOCTYPE html>
# <html>
#   <head>
#   </head>
#   <body>
#       <h1>Herman Melville - Moby-Dick</h1>
#
#       <div>
#         <p>
# ...

# %%
#tarea 3.1
r = requests.get("http://httpbin.org/html")
print("Status:", r.status_code)
print("Headers:", dict(r.headers))
print("Body:", r.text)
# Out:
# Status: 200
# Headers: {'Date': 'Wed, 25 Feb 2026 10:32:09 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '3741', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Body: <!DOCTYPE html>
# <html>
#   <head>
#   </head>
#   <body>
#       <h1>Herman Melville - Moby-Dick</h1>
#
#       <div>
#         <p>
# ...

# %%
#tarea 3.2
r = requests.get("https://httpbin.org/html")
print("Status:", r.status_code)
print("Headers:", dict(r.headers))
print("Body:", r.text)
# Out:
# Status: 200
# Headers: {'Date': 'Wed, 25 Feb 2026 10:32:13 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '3741', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Body: <!DOCTYPE html>
# <html>
#   <head>
#   </head>
#   <body>
#       <h1>Herman Melville - Moby-Dick</h1>
#
#       <div>
#         <p>
# ...

# %%
#tare 4
import requests
from bs4 import BeautifulSoup

url = "https://taibo-gonzalez-manuel.mooo.com/"
r = requests.get(url)

soup = BeautifulSoup(r.text, "html.parser")

parrafos = soup.find_all("p")
print ("numero de parrafos:", len(parrafos))

print("\n--- Etiquetas h1 ---")
for tag in soup.find_all("h1"):
    print(tag.get_text())

print("\n--- Etiquetas h2 ---")
for tag in soup.find_all("h2"):
    print(tag.get_text())

print("\n--- Etiquetas p ---")
for tag in soup.find_all("p"):
    print(tag.get_text())
# Out:
# numero de parrafos: 3
#
# --- Etiquetas h1 ---
# Página Personal
#
# --- Etiquetas h2 ---
# Datos:
#
# --- Etiquetas p ---
# Manuel Taibo González
# manuel.taibo2@udc.es
# Free DNS
